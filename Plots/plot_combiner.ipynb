# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# ------------------------------------------------------------
# PNG files (EDIT names if needed)
# ------------------------------------------------------------
image_paths = [
    ("DNN Control Model",  "dnn_control.png"),
    ("TCN Control Model",  "tcn_control.png"),
    ("DNN Teacher Model",  "dnn_teacher.png"),
    ("DNN Student Model",  "dnn_student.png"),
    ("TCN Student Model",  "tcn_student.png"),
]

# ------------------------------------------------------------
# Create combined figure
# ------------------------------------------------------------
fig, axes = plt.subplots(
    nrows=len(image_paths),
    ncols=1,
    figsize=(14, 20)
)

for ax, (title, img_path) in zip(axes, image_paths):
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.set_title(title, fontsize=13, pad=10)
    ax.axis("off")

plt.tight_layout()
plt.savefig(
    "combined_training_histories.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()
